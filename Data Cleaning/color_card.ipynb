# %%
from plantcv import plantcv as pcv
rgb_img, path, filename = pcv.readimage("/Users/jstanton/desktop/NS004.png")
df, start, space = pcv.transform.find_color_card(rgb_img=rgb_img)

# %%
#Use these outputs to create a labeled color card mask
mask = pcv.transform.create_color_card_mask(rgb_img=rgb_img, radius=10, start_coord=start, spacing=space, ncols=6, nrows=4)
avg_chip_size = pcv.outputs.observations['default']['median_color_chip_height']['value']

# %%
pcv.plot_image(mask)

# %%
avg_chip_size
# Out:
# 37.0
